# %%
import pandas as pd
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_excel(r"C:\Users\PC\Documents\01 KULIAH FAJRIA\WALLAHI SKRISPI\CORE CODING\DATA\buat_validasi.xlsx")
df
# Out:
#                                                   Text                  Label  \
# 0          emng si babi ini ajimumpung ye lo awas aje   Kata Kasar dan Vulgar
# 1                  SAYANGKU LUCU BANGETTT ADEKKKKKKKKK      Non-Cyberbullying
# 2    jjongie pun masih khawatirkan member enha lain...  Kata Kasar dan Vulgar
# 3    anjeng bey lu asli sepengangguran dan seuseles...  Kata Kasar dan Vulgar
# 4    affiliate di tiktok amp shopee masih enak gw l...  Kata Kasar dan Vulgar
# ..                                                 ...                    ...
# 494                                   pengen jilmek ni      Non-Cyberbullying
# 495                                      enak bangettt      Non-Cyberbullying
# 496  guaa siap bangett jadi hatter bayaran si ica b...  Kata Kasar dan Vulgar
# 497  yesex lu bego ya hyukjae KAGA YAA ANJIRR lucu ...  Kata Kasar dan Vulgar
# 498  USER sensi amat dikritik biasa aja kaleee seti...  Kata Kasar dan Vulgar
#
#                   Validasi
# 0    Kata Kasar dan Vulgar
# 1        Non-Cyberbullying
# 2        Non-Cyberbullying
# 3    Kata Kasar dan Vulgar
# 4        Non-Cyberbullying
# ..                     ...
# 494      Sexual Harassment
# 495      Non-Cyberbullying
# 496  Kata Kasar dan Vulgar
# 497      Non-Cyberbullying
# 498  Kata Kasar dan Vulgar
#
# [499 rows x 3 columns]

# %%
kappa = cohen_kappa_score(
    df["Label"],
    df["Validasi"]
)

print(f"Cohen's Kappa: {kappa:.4f}")
# Out:
# Cohen's Kappa: 0.7951

# %%
f1 = f1_score(
    df['Validasi'],
    df['Label'],
    average='macro'
)

print(f"Macro F1-score: {f1:.4f}")
# Out:
# Macro F1-score: 0.8961

# %%
accuracy = accuracy_score(
    df['Validasi'],
    df['Label']
)

print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8938
